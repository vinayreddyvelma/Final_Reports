# %%
#we have first this command that initialize and matplotlib (library) for plotting and we specify that we want those plots inline in this notebook

# NOTE: IF YOU ARE EXECUTING FOR THE FIRST TIME RUN
# %matplotlib inline
# IF YOU ARE EXECUTING FOR THE SECOND TIME IN INTERACTIVE MODE RUN
#%matplotlib nbagg

#now we import different packages that will allow to do math, lineal algebra, numerical operations, array operations and plotting
import scipy as Sci
import scipy.linalg
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt

#we use a simple open command for the file (basic Python)
f = open('UltrasoundSampleSignal.dat','rb')
#we read it using a numpy (therefore the np.) command that allows direct reading from file into an array
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
#to verify the size of the file I am printing here the lenght of that array 
print('\n The length of the file is: ' + str(len(AllSignal)) + ' as expected from 15000 samples x 462 lines')
#we will now populate an array for the time which we now is 1/125MHz step for a total of 15000
x=np.arange(0,15000/125e6,1/125e6)  #start,stop,step
print('\n The length of the time array is: ' + str(len(x)) )
#now we plot only the first line acquired (15000 samples)
plt.plot(x,AllSignal[:15000])
plt.title('First Line Acquired')
plt.xlabel('Time')
plt.ylabel('Unsigned Integer Value')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
f.close() #close the file
# Out:
#  The length of the file is: 6930000 as expected from 15000 samples x 462 lines
#
#  The length of the time array is: 15000

# %% [markdown]
# Introduction
# --------------
#
# The Fourier Transform is one of the most powerful and well known tools to analyse frequency behaviour. As such, it allows performing many operations in signal and imaging processing such as filtering, signal evaluation, signal characterization, etc.
#
# In particular for medical applications some of the most widespread applications of Fourier Transform in signal processing are:
# 1. Filtering the signal to extract the information from the noise (i.e. the respiration rate will add important noise to an ECG signal but its frequency is much lower and can then be subtracted)
# 2. Evaluating the magnitude at specific frequencies of the signal to evaluate thresholds in an acquired signal (i.e. the detection of a seizure onset in EEG is characterized for large broadband signals)
# 3. The appearance of harmonics within a signal which may indicate there is an abnormality (i.e. the detection of harmonics in an ECG may indicate an arhytmia)
#
# Fourier transforms present important properties that allow to combine analysis in frequency with simplicity:
# 1. Linearity: the transform of a sum is the sum of the transforms
# 2. Symmetry: the transform of the negative frequency is the conjugate of the transform
# 3. Convolution: the transform of a convolution is the product of each transform
#
# In addition, filter design using frequency response is an important feature, and analysis of the response of a digital filter is usually done as a function of frequency:
# 1. It is often necessary to understand the behaviour of your signal before proposing the design of a filter
# 2. Once a filter is chosen, the impact of the order on the frequency behaviour of the filter and how that may affect the signal is important
#
# The Discrete Fourier Transform (DFT) is the primary analysis tool for Fourier Transform nowadays since much of the processing is performed on digitized signals.
#
# Using the DFT is equivalent to obtain a periodic signal out of a sequence (samples) of values.
#
# This notebook will show how the DFT is implemented on a signal and how we can detect the presence and main frequency components of noise within the signal as well as the main frequency of the signal of interest.
#
# We will work on an ultrasound signal that was acquired over time where some noise appears at some time point (we will determine when) and we will analyse the frequency component of the noise and the signal.
#
# Some specifics about this acquired file: we obtained 15000 samples with a frequency of sampling of 125MHz, then waited another trigger and repeated for a total of 462 times.
#
# We will also use this as an example on Python and simple signal analysis using Python.
#
# We will start by opening the binary file where the signal was stored in unsigned integer (16 bits) and reading all the data into an array:

# %%
#We continue plotting other lines (we will plot every line and there are 462) 
totlines=np.arange(462)
for index in totlines:
    Signal=AllSignal[index*15000:(index+1)*15000]
    plt.plot(x,AllSignal[index*15000:(index+1)*15000])
    plt.xlabel('Time')
    plt.ylabel('Unsigned Integer Value')
    plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# We can see from above that there are some lines that have noise.
#
# We will first analyse the frequency component of a clean and a noisy line.

# %%
#The first line is clear
FirstLine=AllSignal[:15000]

#But some lines are very noisy, for instance line 172
NoisyLine=AllSignal[200*15000:(200+1)*15000]

plt.subplots_adjust( hspace = .5 )
plt.subplot(211)
plt.plot(x,FirstLine)
plt.ylabel('Fist line - No noise')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.subplot(212)
plt.plot(x,NoisyLine)
plt.xlabel('Time')
plt.ylabel('Line 172-Noise')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# Now that we have a noisy and a clean line we will obtain the frequency component of those signals using DFT.
#
# First lets define the DFT:
#
# $$ A_k=\sum_{m=0}^{n-1}a_m \exp \left(-2\pi i \frac{mk}{n} \right ) [k=0,...,n-1] $$
#
# If we notice the signal has a dc component (not centered in zero) so unless we want to have a spectrum with a large value of dc or zero frequency we will first remove the dc component (by substracting the mean of the data).
#
# We will then obtain the DFT.

# %%
#we first eliminate dc
# %matplotlib nbagg
dataF=FirstLine-np.mean(FirstLine)
L=len(dataF)
#the frequencies after fft will be between 0 and 1/2 of the sampling frequency
f=np.arange(0,125e6/2,125e6/15000)
Y=np.fft.fft(dataF)
PyyClean=abs(Y)/L
#note: we are showing just L/2 elements which are the positive frequencies and we are normalizing
plt.subplot(121)
plt.plot(f, PyyClean[:7500])
plt.title('DFT of clean line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#Zooming into just less than 15MHz
inx=np.where(f>15e6)
inx=inx[0]
plt.subplot(122)
plt.plot(f[:inx[0]], PyyClean[:inx[0]])
plt.title('DFT of clean line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#now we repeat for the noisy line
#we first eliminate dc
dataN=NoisyLine-np.mean(NoisyLine)
L=len(dataN)
#the frequencies after fft will be between 0 and 1/2 of the sampling frequency
f=np.arange(0,125e6/2,125e6/15000)
Y=np.fft.fft(dataN)
PyyNoisy=abs(Y)/L
#note: we are showing just L/2 elements which are the positive frequencies and we are normalizing
plt.subplot(121)
plt.plot(f, PyyNoisy[:7500])
plt.title('DFT of noisy line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#Zooming into just less than 15MHz
inx=np.where(f>15e6)
inx=inx[0]
plt.subplot(122)
plt.plot(f[:inx[0]], PyyNoisy[:inx[0]])
plt.title('DFT of noisy line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# We can clearly see there are large noise peaks at various frequencies. These are actually harmonics of 1.5MHz and it is strong at 4.5MHz.
#
# We will use this here to determine a criteria for noise and later on to filter this signal.
#
# A nice tool: let's use interactive graph to "see" where those peaks are. For this, the backend for matplotlib to use is called nbagg so we will change the inline magic for **nbagg**.
#
# Go up in the code and change the magic command ```python %matplotlib inline``` for ```python %matplotlib nbagg``` and you will now be in **interactive mode**.
#
# **BEFORE YOU RUN** select the option "Kernel->Restart" or the rendering will fail.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this example, we executed the Discrete Fourier Transform (DFT) on a clear and noisy signal.
#
# Test your knowdelge:
#
# Find which line(s) in the acquisition have a noticeable noise (we will define this point as when the noise peak at 4.5MHz reaches an amplitude in the FFT as high as the maximum in the clear line)
#     1. Use a loop in the code
#     2. Display all the line numbers that fall under this criteria
#     3. Display the amplitude of the peak at 4.5MHz for each noisy line
#
# Comments and corrections welcome!

# %% [markdown]
# References
# ---------------
#
# * Oppenheim, A. V., and A. S. Willsky. "Signals and Systems." Prentice-Hall, (1997).

# %% [markdown]
# # Q&A

# %% [markdown]
# To find noise threshold i.e amplitude of clean line at 4.5 MHz. we can find that peak using np.amax command.

# %%
c=np.amax(PyyClean)
print "Noise Threshold is  " + str(c)
# Out:
# Noise Threshold is  120.198226193

# %%
totlines=np.arange(462)
h=0
for index in totlines:
    dataN=AllSignal[index*15000:(index+1)*15000]-np.mean(AllSignal[index*15000:(index+1)*15000])
    I=len(dataN)
    T=np.fft.fft(dataN)
    Pyy=abs(T)/I
    y=np.amax(Pyy)   
    if y>120.19:     
        h=h+1 
        print "line" +str(index) + "above noise threshold" 
print "Total Number of Noise lines are  " + str(h)
# Out:
# line0above noise threshold
# line74above noise threshold
# line75above noise threshold
# line83above noise threshold
# line84above noise threshold
# line85above noise threshold
# line86above noise threshold
# line87above noise threshold
# line88above noise threshold
# line89above noise threshold
# line90above noise threshold
# line91above noise threshold
# line92above noise threshold
# line93above noise threshold
# line94above noise threshold
# line95above noise threshold
# line96above noise threshold
# line97above noise threshold
# line98above noise threshold
# line99above noise threshold
# line100above noise threshold
# line101above noise threshold
# line102above noise threshold
# line103above noise threshold
# line104above noise threshold
# line105above noise threshold
# line106above noise threshold
# line107above noise threshold
# line108above noise threshold
# line109above noise threshold
# line110above noise threshold
# line111above noise threshold
# line112above noise threshold
# line113above noise threshold
# line114above noise threshold
# line115above noise threshold
# line116above noise threshold
# line117above noise threshold
# line149above noise threshold
# line150above noise threshold
# line151above noise threshold
# line152above noise threshold
# line153above noise threshold
# line154above noise threshold
# line155above noise threshold
# line156above noise threshold
# line157above noise threshold
# line158above noise threshold
# line159above noise threshold
# line160above noise threshold
# line161above noise threshold
# line162above noise threshold
# line163above noise threshold
# line164above noise threshold
# line165above noise threshold
# line166above noise threshold
# line167above noise threshold
# line168above noise threshold
# line169above noise threshold
# line170above noise threshold
# line171above noise threshold
# line172above noise threshold
# line173above noise threshold
# line174above noise threshold
# line175above noise threshold
# line176above noise threshold
# line177above noise threshold
# line178above noise threshold
# line179above noise threshold
# line180above noise threshold
# line181above noise threshold
# line182above noise threshold
# line183above noise threshold
# line184above noise threshold
# line185above noise threshold
# line186above noise threshold
# line187above noise threshold
# line214above noise threshold
# line215above noise threshold
# line216above noise threshold
# line217above noise threshold
# line218above noise threshold
# line219above noise threshold
# line220above noise threshold
# line221above noise threshold
# line222above noise threshold
# line223above noise threshold
# line224above noise threshold
# line225above noise threshold
# line226above noise threshold
# line227above noise threshold
# line228above noise threshold
# line229above noise threshold
# line230above noise threshold
# line231above noise threshold
# line232above noise threshold
# line233above noise threshold
# line234above noise threshold
# line235above noise threshold
# line236above noise threshold
# line237above noise threshold
# line238above noise threshold
# line239above noise threshold
# line240above noise threshold
# line241above noise threshold
# line242above noise threshold
# line243above noise threshold
# line244above noise threshold
# line245above noise threshold
# line246above noise threshold
# line247above noise threshold
# line248above noise threshold
# line249above noise threshold
# line250above noise threshold
# line251above noise threshold
# line252above noise threshold
# line264above noise threshold
# line268above noise threshold
# line269above noise threshold
# line270above noise threshold
# line271above noise threshold
# line272above noise threshold
# line273above noise threshold
# line274above noise threshold
# line275above noise threshold
# line276above noise threshold
# line277above noise threshold
# line278above noise threshold
# line279above noise threshold
# line280above noise threshold
# line281above noise threshold
# line282above noise threshold
# line283above noise threshold
# line284above noise threshold
# line285above noise threshold
# line286above noise threshold
# line287above noise threshold
# line288above noise threshold
# line289above noise threshold
# line290above noise threshold
# line291above noise threshold
# line292above noise threshold
# line293above noise threshold
# line294above noise threshold
# line295above noise threshold
# line296above noise threshold
# line297above noise threshold
# line298above noise threshold
# line299above noise threshold
# line300above noise threshold
# line301above noise threshold
# line302above noise threshold
# line303above noise threshold
# line304above noise threshold
# line305above noise threshold
# line306above noise threshold
# line307above noise threshold
# line308above noise threshold
# line309above noise threshold
# line310above noise threshold
# line311above noise threshold
# line312above noise threshold
# line313above noise threshold
# line314above noise threshold
# line315above noise threshold
# line316above noise threshold
# line317above noise threshold
# line318above noise threshold
# line319above noise threshold
# line320above noise threshold
# line321above noise threshold
# line322above noise threshold
# line323above noise threshold
# line324above noise threshold
# line325above noise threshold
# line326above noise threshold
# line327above noise threshold
# line328above noise threshold
# line329above noise threshold
# line330above noise threshold
# line331above noise threshold
# line332above noise threshold
# line333above noise threshold
# line334above noise threshold
# line335above noise threshold
# line336above noise threshold
# line337above noise threshold
# line338above noise threshold
# line339above noise threshold
# line340above noise threshold
# line341above noise threshold
# line342above noise threshold
# line343above noise threshold
# line344above noise threshold
# line345above noise threshold
# line346above noise threshold
# line347above noise threshold
# line348above noise threshold
# line349above noise threshold
# line350above noise threshold
# line351above noise threshold
# line352above noise threshold
# line353above noise threshold
# line354above noise threshold
# line355above noise threshold
# line356above noise threshold
# line357above noise threshold
# line358above noise threshold
# line359above noise threshold
# line360above noise threshold
# line361above noise threshold
# line362above noise threshold
# line363above noise threshold
# line364above noise threshold
# line365above noise threshold
# line366above noise threshold
# line367above noise threshold
# line368above noise threshold
# line369above noise threshold
# line370above noise threshold
# line371above noise threshold
# line372above noise threshold
# line373above noise threshold
# line374above noise threshold
# line375above noise threshold
# line376above noise threshold
# line377above noise threshold
# line378above noise threshold
# line379above noise threshold
# line380above noise threshold
# line381above noise threshold
# line382above noise threshold
# line383above noise threshold
# line384above noise threshold
# line385above noise threshold
# line386above noise threshold
# line387above noise threshold
# line388above noise threshold
# line389above noise threshold
# line390above noise threshold
# line391above noise threshold
# line392above noise threshold
# line393above noise threshold
# line394above noise threshold
# line395above noise threshold
# line396above noise threshold
# line397above noise threshold
# line398above noise threshold
# line399above noise threshold
# line400above noise threshold
# line401above noise threshold
# line402above noise threshold
# line403above noise threshold
# line404above noise threshold
# line405above noise threshold
# line406above noise threshold
# line407above noise threshold
# line408above noise threshold
# line409above noise threshold
# line410above noise threshold
# line411above noise threshold
# line412above noise threshold
# line413above noise threshold
# line414above noise threshold
# line415above noise threshold
# line416above noise threshold
# line417above noise threshold
# line418above noise threshold
# line419above noise threshold
# line420above noise threshold
# line421above noise threshold
# line422above noise threshold
# line423above noise threshold
# line424above noise threshold
# line425above noise threshold
# line426above noise threshold
# line427above noise threshold
# line428above noise threshold
# line429above noise threshold
# line430above noise threshold
# line431above noise threshold
# line432above noise threshold
# line433above noise threshold
# line434above noise threshold
# line435above noise threshold
# line436above noise threshold
# line437above noise threshold
# line438above noise threshold
# line439above noise threshold
# line440above noise threshold
# line441above noise threshold
# line442above noise threshold
# line443above noise threshold
# line444above noise threshold
# line445above noise threshold
# line446above noise threshold
# line447above noise threshold
# line448above noise threshold
# line449above noise threshold
# line450above noise threshold
# line451above noise threshold
# line452above noise threshold
# line453above noise threshold
# line454above noise threshold
# line455above noise threshold
# line456above noise threshold
# line457above noise threshold
# line458above noise threshold
# line459above noise threshold
# line460above noise threshold
# line461above noise threshold
# Total Number of Noise lines are  311
